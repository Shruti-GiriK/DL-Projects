# %% [markdown]
# <a href="https://colab.research.google.com/github/Shruti-GiriK/DL-Projects/blob/main/Text_Classification_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Text Classification - Understanding the Sentiment by The Reviews**

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## **Data Understanding**

# %%
df=pd.read_csv('/content/cleaned_reviews.csv')
df
# Out:
#       sentiments                                     cleaned_review  \
# 0       positive  i wish would have gotten one earlier love it a...
# 1        neutral  i ve learned this lesson again open the packag...
# 2        neutral          it is so slow and lags find better option
# 3        neutral  roller ball stopped working within months of m...
# 4        neutral  i like the color and size but it few days out ...
# ...          ...                                                ...
# 17335   positive  i love this speaker and love can take it anywh...
# 17336   positive  i use it in my house easy to connect and loud ...
# 17337   positive  the bass is good and the battery is amazing mu...
# 17338   positive                                            love it
# 17339    neutral                                       mono speaker
#
#        cleaned_review_length  review_score
# 0                         19           5.0
# 1                         88           1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17340 entries, 0 to 17339
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sentiments             17340 non-null  object
#  1   cleaned_review         17337 non-null  object
#  2   cleaned_review_length  17340 non-null  int64
#  3   review_score           17340 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 542.0+ KB

# %% [markdown]
# ## **Data Cleaning**

# %%
df.isnull().sum()
# Out:
# sentiments               0
# cleaned_review           3
# cleaned_review_length    0
# review_score             0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#       sentiments                                     cleaned_review  \
# 0       positive  i wish would have gotten one earlier love it a...
# 1        neutral  i ve learned this lesson again open the packag...
# 2        neutral          it is so slow and lags find better option
# 3        neutral  roller ball stopped working within months of m...
# 4        neutral  i like the color and size but it few days out ...
# ...          ...                                                ...
# 17335   positive  i love this speaker and love can take it anywh...
# 17336   positive  i use it in my house easy to connect and loud ...
# 17337   positive  the bass is good and the battery is amazing mu...
# 17338   positive                                            love it
# 17339    neutral                                       mono speaker
#
#        cleaned_review_length  review_score
# 0                         19           5.0
# 1                         88           1.0
# ...

# %%
print(df[df.duplicated()])
# Out:
#       sentiments cleaned_review  cleaned_review_length  review_score
# 308     positive        love it                      2           5.0
# 468      neutral           junk                      1           5.0
# 540     positive        love it                      2           5.0
# 635     positive    works great                      2           5.0
# 807     positive    works great                      2           5.0
# ...          ...            ...                    ...           ...
# 17281    neutral                                     0           5.0
# 17311    neutral      excelente                      1           5.0
# 17313    neutral      excelente                      1           5.0
# 17314   positive       awesome                       1           5.0
# 17338   positive        love it                      2           5.0
#
# [1347 rows x 4 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
print(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [sentiments, cleaned_review, cleaned_review_length, review_score]
# Index: []

# %%
df
# Out:
#       sentiments                                     cleaned_review  \
# 0       positive  i wish would have gotten one earlier love it a...
# 1        neutral  i ve learned this lesson again open the packag...
# 2        neutral          it is so slow and lags find better option
# 3        neutral  roller ball stopped working within months of m...
# 4        neutral  i like the color and size but it few days out ...
# ...          ...                                                ...
# 17334   positive  i bought it to keep it at work and everyone lo...
# 17335   positive  i love this speaker and love can take it anywh...
# 17336   positive  i use it in my house easy to connect and loud ...
# 17337   positive  the bass is good and the battery is amazing mu...
# 17339    neutral                                       mono speaker
#
#        cleaned_review_length  review_score
# 0                         19           5.0
# 1                         88           1.0
# ...

# %%
df.describe()
# Out:
#        cleaned_review_length  review_score
# count           15990.000000  15990.000000
# mean               31.048155      3.635272
# std                36.081638      1.665071
# min                 0.000000      1.000000
# 25%                 9.000000      2.000000
# 50%                20.000000      5.000000
# 75%                39.000000      5.000000
# max               571.000000      5.000000

# %%
df.drop(['review_score','cleaned_review_length'],axis=1,inplace=True)

# %%
df['sentiments'].replace(['Negative','Neutral','Positive'],[1,2,3],inplace=True)

# %%
df
# Out:
#       sentiments                                     cleaned_review
# 0       positive  i wish would have gotten one earlier love it a...
# 1        neutral  i ve learned this lesson again open the packag...
# 2        neutral          it is so slow and lags find better option
# 3        neutral  roller ball stopped working within months of m...
# 4        neutral  i like the color and size but it few days out ...
# ...          ...                                                ...
# 17334   positive  i bought it to keep it at work and everyone lo...
# 17335   positive  i love this speaker and love can take it anywh...
# 17336   positive  i use it in my house easy to connect and loud ...
# 17337   positive  the bass is good and the battery is amazing mu...
# 17339    neutral                                       mono speaker
#
# [15990 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(df['cleaned_review'],df['sentiments'],test_size=0.2,random_state=42)

# %%
vectorizer=TfidfVectorizer()
xtrain_vec=vectorizer.fit_transform(xtrain)
xtest_vec=vectorizer.transform(xtest)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(xtrain_vec,ytrain)
# Out:
# RandomForestClassifier()

# %%
model.predict(vectorizer.transform(['Its  a bad product']))
# Out:
# array(['negative'], dtype=object)

# %%
model.predict(vectorizer.transform(['Its an okay-ish product']))
# Out:
# array(['neutral'], dtype=object)

# %%
model.predict(vectorizer.transform(['I love this product, Its soo nice !!']))
# Out:
# array(['positive'], dtype=object)

# %%
model.score(xtest_vec,ytest)
# Out:
# 0.8433395872420263
